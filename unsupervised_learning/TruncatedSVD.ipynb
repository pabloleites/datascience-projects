# %% [markdown]
# # Clustering Wikipedia Articles
# TruncatedSVD is able to perform PCA on sparse arrays in csr_matrix format, such as word-frequency arrays.
# Here we will combine TrucatedSVD with k-means to cluster some popular pages from the Wikipedia.
#
# Trucnated SVD performs linear dimensionality reduction by means of truncated singular value decomposition (SVD). Contrary to PCA, this estimator does not center the data before computing the singular value decomposition. This means it can work with sparse matrices efficiently.

# %%
import pandas as pd
from sklearn.decomposition import TruncatedSVD
from sklearn.cluster import KMeans
from sklearn.pipeline import make_pipeline
from scipy.sparse import csr_matrix

# %%
df = pd.read_csv('datasets/wikipedia-vectors.csv', index_col=0)
articles = csr_matrix(df.transpose())
titles = list(df.columns)

# %%
svd = TruncatedSVD(n_components=50)
kmeans = KMeans(n_clusters=6)
pipeline = make_pipeline(svd,kmeans)
# Fit the pipeline to articles
pipeline.fit(articles)
# Calculate the cluster labels
labels = pipeline.predict(articles)
# Create a DataFrame aligning labels and titles
df = pd.DataFrame({'label': labels, 'article': titles})

# %%
#Set up visualization
def highlight(row):
    options = {0:'LightYellow',1:'Moccasin',2:'Khaki',3:'Gold',4:'Coral',5:'Tomato'}
    color = options.get(row.values[0])
    return ['background-color: %s' % color]*len(row.values)
df.sort_values('label').style.apply(highlight, axis=1)
# Out:
# <style  type="text/css" >
# #T_9c295_row0_col0,#T_9c295_row0_col1,#T_9c295_row1_col0,#T_9c295_row1_col1,#T_9c295_row2_col0,#T_9c295_row2_col1,#T_9c295_row3_col0,#T_9c295_row3_col1,#T_9c295_row4_col0,#T_9c295_row4_col1,#T_9c295_row5_col0,#T_9c295_row5_col1,#T_9c295_row6_col0,#T_9c295_row6_col1,#T_9c295_row7_col0,#T_9c295_row7_col1,#T_9c295_row8_col0,#T_9c295_row8_col1,#T_9c295_row9_col0,#T_9c295_row9_col1{
#             background-color:  LightYellow;
#         }#T_9c295_row10_col0,#T_9c295_row10_col1,#T_9c295_row11_col0,#T_9c295_row11_col1,#T_9c295_row12_col0,#T_9c295_row12_col1,#T_9c295_row13_col0,#T_9c295_row13_col1,#T_9c295_row14_col0,#T_9c295_row14_col1,#T_9c295_row15_col0,#T_9c295_row15_col1,#T_9c295_row16_col0,#T_9c295_row16_col1,#T_9c295_row17_col0,#T_9c295_row17_col1,#T_9c295_row18_col0,#T_9c295_row18_col1,#T_9c295_row19_col0,#T_9c295_row19_col1{
#             background-color:  Moccasin;
#         }#T_9c295_row20_col0,#T_9c295_row20_col1,#T_9c295_row21_col0,#T_9c295_row21_col1,#T_9c295_row22_col0,#T_9c295_row22_col1,#T_9c295_row23_col0,#T_9c295_row23_col1,#T_9c295_row24_col0,#T_9c295_row24_col1,#T_9c295_row25_col0,#T_9c295_row25_col1,#T_9c295_row26_col0,#T_9c295_row26_col1,#T_9c295_row27_col0,#T_9c295_row27_col1,#T_9c295_row28_col0,#T_9c295_row28_col1,#T_9c295_row29_col0,#T_9c295_row29_col1{
#             background-color:  Khaki;
#         }#T_9c295_row30_col0,#T_9c295_row30_col1,#T_9c295_row31_col0,#T_9c295_row31_col1,#T_9c295_row32_col0,#T_9c295_row32_col1,#T_9c295_row33_col0,#T_9c295_row33_col1,#T_9c295_row34_col0,#T_9c295_row34_col1,#T_9c295_row35_col0,#T_9c295_row35_col1,#T_9c295_row36_col0,#T_9c295_row36_col1,#T_9c295_row37_col0,#T_9c295_row37_col1,#T_9c295_row38_col0,#T_9c295_row38_col1,#T_9c295_row39_col0,#T_9c295_row39_col1{
#             background-color:  Gold;
#         }#T_9c295_row40_col0,#T_9c295_row40_col1,#T_9c295_row41_col0,#T_9c295_row41_col1,#T_9c295_row42_col0,#T_9c295_row42_col1,#T_9c295_row43_col0,#T_9c295_row43_col1,#T_9c295_row44_col0,#T_9c295_row44_col1,#T_9c295_row45_col0,#T_9c295_row45_col1,#T_9c295_row46_col0,#T_9c295_row46_col1,#T_9c295_row47_col0,#T_9c295_row47_col1,#T_9c295_row48_col0,#T_9c295_row48_col1,#T_9c295_row49_col0,#T_9c295_row49_col1{
#             background-color:  Coral;
#         }#T_9c295_row50_col0,#T_9c295_row50_col1,#T_9c295_row51_col0,#T_9c295_row51_col1,#T_9c295_row52_col0,#T_9c295_row52_col1,#T_9c295_row53_col0,#T_9c295_row53_col1,#T_9c295_row54_col0,#T_9c295_row54_col1,#T_9c295_row55_col0,#T_9c295_row55_col1,#T_9c295_row56_col0,#T_9c295_row56_col1,#T_9c295_row57_col0,#T_9c295_row57_col1,#T_9c295_row58_col0,#T_9c295_row58_col1,#T_9c295_row59_col0,#T_9c295_row59_col1{
#             background-color:  Tomato;
#         }</style><table id="T_9c295_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >label</th>        <th class="col_heading level0 col1" >article</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9c295_level0_row0" class="row_heading level0 row0" >14</th>
#                         <td id="T_9c295_row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_9c295_row0_col1" class="data row0 col1" >Climate change</td>
#             </tr>
#             <tr>
#                         <th id="T_9c295_level0_row1" class="row_heading level0 row1" >17</th>
#                         <td id="T_9c295_row1_col0" class="data row1 col0" >0</td>
#                         <td id="T_9c295_row1_col1" class="data row1 col1" >Greenhouse gas emissions by the United States</td>
#             </tr>
#             <tr>
#                         <th id="T_9c295_level0_row2" class="row_heading level0 row2" >13</th>
#                         <td id="T_9c295_row2_col0" class="data row2 col0" >0</td>
#                         <td id="T_9c295_row2_col1" class="data row2 col1" >Connie Hedegaard</td>
#             </tr>
#             <tr>
#                         <th id="T_9c295_level0_row3" class="row_heading level0 row3" >12</th>
#                         <td id="T_9c295_row3_col0" class="data row3 col0" >0</td>
#                         <td id="T_9c295_row3_col1" class="data row3 col1" >Nigel Lawson</td>
#             </tr>
#             <tr>
#                         <th id="T_9c295_level0_row4" class="row_heading level0 row4" >11</th>
#                         <td id="T_9c295_row4_col0" class="data row4 col0" >0</td>
#                         <td id="T_9c295_row4_col1" class="data row4 col1" >Nationally Appropriate Mitigation Action</td>
#             </tr>
#             <tr>
#                         <th id="T_9c295_level0_row5" class="row_heading level0 row5" >10</th>
#                         <td id="T_9c295_row5_col0" class="data row5 col0" >0</td>
#                         <td id="T_9c295_row5_col1" class="data row5 col1" >Global warming</td>
#             </tr>
#             <tr>
#                         <th id="T_9c295_level0_row6" class="row_heading level0 row6" >18</th>
#                         <td id="T_9c295_row6_col0" class="data row6 col0" >0</td>
#                         <td id="T_9c295_row6_col1" class="data row6 col1" >2010 United Nations Climate Change Conference</td>
#             </tr>
#             <tr>
#                         <th id="T_9c295_level0_row7" class="row_heading level0 row7" >15</th>
#                         <td id="T_9c295_row7_col0" class="data row7 col0" >0</td>
#                         <td id="T_9c295_row7_col1" class="data row7 col1" >Kyoto Protocol</td>
#             </tr>
#             <tr>
#                         <th id="T_9c295_level0_row8" class="row_heading level0 row8" >19</th>
#                         <td id="T_9c295_row8_col0" class="data row8 col0" >0</td>
#                         <td id="T_9c295_row8_col1" class="data row8 col1" >2007 United Nations Climate Change Conference</td>
#             </tr>
#             <tr>
#                         <th id="T_9c295_level0_row9" class="row_heading level0 row9" >16</th>
#                         <td id="T_9c295_row9_col0" class="data row9 col0" >0</td>
#                         <td id="T_9c295_row9_col1" class="data row9 col1" >350.org</td>
#             </tr>
#             <tr>
#                         <th id="T_9c295_level0_row10" class="row_heading level0 row10" >21</th>
#                         <td id="T_9c295_row10_col0" class="data row10 col0" >1</td>
#                         <td id="T_9c295_row10_col1" class="data row10 col1" >Michael Fassbender</td>
#             </tr>
#             <tr>
#                         <th id="T_9c295_level0_row11" class="row_heading level0 row11" >22</th>
#                         <td id="T_9c295_row11_col0" class="data row11 col0" >1</td>
#                         <td id="T_9c295_row11_col1" class="data row11 col1" >Denzel Washington</td>
#             </tr>
#             <tr>
#                         <th id="T_9c295_level0_row12" class="row_heading level0 row12" >23</th>
#                         <td id="T_9c295_row12_col0" class="data row12 col0" >1</td>
#                         <td id="T_9c295_row12_col1" class="data row12 col1" >Catherine Zeta-Jones</td>
#             </tr>
#             <tr>
#                         <th id="T_9c295_level0_row13" class="row_heading level0 row13" >24</th>
#                         <td id="T_9c295_row13_col0" class="data row13 col0" >1</td>
#                         <td id="T_9c295_row13_col1" class="data row13 col1" >Jessica Biel</td>
#             </tr>
#             <tr>
#                         <th id="T_9c295_level0_row14" class="row_heading level0 row14" >25</th>
#                         <td id="T_9c295_row14_col0" class="data row14 col0" >1</td>
#                         <td id="T_9c295_row14_col1" class="data row14 col1" >Russell Crowe</td>
#             </tr>
#             <tr>
#                         <th id="T_9c295_level0_row15" class="row_heading level0 row15" >26</th>
#                         <td id="T_9c295_row15_col0" class="data row15 col0" >1</td>
#                         <td id="T_9c295_row15_col1" class="data row15 col1" >Mila Kunis</td>
#             </tr>
#             <tr>
